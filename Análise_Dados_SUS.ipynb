# %% [markdown]
# # Análise dos dados do SUS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uri = 'https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A151346189_28_143_208.csv'

uri2 = 'https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A160324189_28_143_208.csv'

# %% [markdown]
# Vamos definir uma variável para armazenar nossos dataframe:

# %%
dados = pd.read_csv(uri, sep = ';', encoding='ISO-8859-1', skiprows=3,
                    skipfooter=12, thousands = '.', decimal = ',')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.

# %% [markdown]
# Passamos alguns parâmetros especiais:
#
# - definimos o separador como ;
# - o tipo de codificação como 'ISO-8859-1'
# - retiramos as 3 linhas vazias com o parâmetro 'skiprows'
# - retiramos as 12 linhas vazias no rodapé com o parâmetro 'skipfooter'
# - definimos o separador de milhares como '.' e o separador de decimais como ','

# %%
dados.head()
# Out:
#   Unidade da Federação     2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia   1388528.39  ...  10285455.78  9.291297e+08
# 1              12 Acre    902416.00  ...            -  4.206680e+08
# 2          13 Amazonas   4735529.42  ...  14726443.67  1.771655e+09
# 3           14 Roraima    657889.53  ...   2826486.18  3.050109e+08
# 4              15 Pará  18864744.11  ...  39911193.02  4.437116e+09
#
# [5 rows x 154 columns]

# %% [markdown]
# Os dados, embora aparentemente numéricos, estão no formato string. Iremos converter para o tipo float, com o código abaixo:

# %%
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# A coluna 2020/Ago possui um campo faltante, que no caso representa o estado do Acre. Iremos preencher o campo com o valor '0'. E após isso converter essa coluna para o tipo float.

# %%
dados['2020/Ago'] = dados['2020/Ago'].replace('-', 0.0)

# %%
dados['2020/Ago'] = dados['2020/Ago'].astype('float')

# %%
dados = dados.sort_values('2020/Ago', ascending=True)

# %% [markdown]
# ---

# %% [markdown]
# Desafio 01: Escolher um título mais descritivo, que passe a mensagem adequada ao gráfico de barras.
#
# Desafio 02: Faça a mesma análise realizada em aula, porém para o mês mais recente.

# %%
import matplotlib.ticker as ticker


plt.figure(figsize=(16,7))
ax = sns.barplot(x='2020/Ago', y='Unidade da Federação', data=dados)
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('Valores por Estado de Processamento Hospitalares', fontsize=18)

plt.xticks(fontsize=14, rotation=30)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# Vamos agora exportar outra base de dados:

# %%
dados2 = pd.read_csv(uri2, sep = ';', encoding='ISO-8859-1', skiprows=3,
                    skipfooter=12, thousands = '.', decimal = ',')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.

# %%
dados2.head(4)
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2020/Jul    2020/Ago         Total
# 0          11 Rondônia        -        -  ...  7407388.24  3556381.57  929129659.72
# 1              12 Acre        -        -  ...  1163813.08           -  420668039.63
# 2          13 Amazonas        -        -  ... 13358514.02  4726485.73 1771654871.23
# 3           14 Roraima        -        -  ...  2739498.41  1524478.04  305010883.18
#
# [4 rows x 280 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
colunas_usaveis = dados2.mean().index.tolist()

# %%
dados2[colunas_usaveis].head(4)
# Out:
#    2007/Ago  2007/Set  2007/Out  ...    2020/Jun    2020/Jul         Total
# 0   4209.37  16397.03 133645.19  ...  9193593.76  7407388.24  929129659.72
# 1  10470.07  14001.71  86200.85  ...  2199920.70  1163813.08  420668039.63
# 2  35752.72  45570.64 416012.30  ... 17509334.66 13358514.02 1771654871.23
# 3   4785.91  11858.63  43852.67  ...  3216466.51  2739498.41  305010883.18
#
# [4 rows x 157 columns]

# %% [markdown]
# Vamos adicionar a coluna 'Unidade da Federação' na posição 0:

# %%
colunas_usaveis.insert(0, 'Unidade da Federação')

# %%
dados_usaveis = dados2[colunas_usaveis]
dados_usaveis.head(4)
# Out:
#   Unidade da Federação  2007/Ago  ...    2020/Jul         Total
# 0          11 Rondônia   4209.37  ...  7407388.24  929129659.72
# 1              12 Acre  10470.07  ...  1163813.08  420668039.63
# 2          13 Amazonas  35752.72  ... 13358514.02 1771654871.23
# 3           14 Roraima   4785.91  ...  2739498.41  305010883.18
#
# [4 rows x 158 columns]

# %% [markdown]
# Vamos setar a coluna 'Unidade da Federação' como o nosso índice para facilitar nas análises:

# %%
dados_usaveis = dados_usaveis.set_index('Unidade da Federação')
dados_usaveis.head(4)
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  929129659.72
# 12 Acre               10470.07  14001.71  ...  1163813.08  420668039.63
# 13 Amazonas           35752.72  45570.64  ... 13358514.02 1771654871.23
# 14 Roraima             4785.91  11858.63  ...  2739498.41  305010883.18
#
# [4 rows x 157 columns]

# %% [markdown]
# Vamos utilizar a matriz transposta para reordenar nosso dataframe:

# %%
dados_usaveis = dados_usaveis.T

# %%
dados_usaveis.tail()
# Out:
# Unidade da Federação  11 Rondônia  ...  53 Distrito Federal
# 2020/Abr               7423678.64  ...          18123899.78
# 2020/Mai               8581195.13  ...          21437430.22
# 2020/Jun               9193593.76  ...          23479773.03
# 2020/Jul               7407388.24  ...          22233542.26
# Total                929129659.72  ...        2429933198.76
#
# [5 rows x 27 columns]

# %% [markdown]
# Vamos dropar a linha 'Total' pois os valores são bem altos e irá atrapalhar nas nossas visualizações futuras.

# %%
dados_usaveis = dados_usaveis.drop('Total', axis=0)

# %%
dados_usaveis.tail()
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  ...    52 Goiás  53 Distrito Federal
# 2020/Mar               7174312.31 2859102.06  ... 34558308.52          19405446.88
# 2020/Abr               7423678.64 2472063.08  ... 27499307.93          18123899.78
# 2020/Mai               8581195.13 2383895.48  ... 31870107.62          21437430.22
# 2020/Jun               9193593.76 2199920.70  ... 34437633.20          23479773.03
# 2020/Jul               7407388.24 1163813.08  ... 33499284.38          22233542.26
#
# [5 rows x 27 columns]

# %% [markdown]
# Perfeito! Agora com a linha apagada, vamos ao desafio de colocar a legenda num local apropriado:

# %%
import matplotlib.ticker as ticker
ax = dados_usaveis.plot(figsize=(20,6))
plt.legend(bbox_to_anchor=(1.0, 1.0), loc="upper left", ncol=2, fontsize=14)
plt.title('Gastos por Estados', fontsize=18)
plt.xlabel('Ano', fontsize = 14)
plt.ylabel('Valor em Bilhões', fontsize=14)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))
plt.show()

# %% [markdown]
# E agora, vamos ao desafio de plotar um gráfico de apenas 5 estados:

# %%
estados = ['31 Minas Gerais','32 Espírito Santo','33 Rio de Janeiro', '35 São Paulo', '41 Paraná']
estados2 = dados_usaveis[estados]

# %%
from plotly.offline import iplot
import cufflinks as cf
import matplotlib.ticker as ticker

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import plotly.io as pio
pio.renderers.default = 'colab'
estados2.iplot(yTitle='Valor em Bilhões', xTitle='Anos', title='Cinco maiores estados com gastos hospitalares')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="07857d2a-bf34-4950-9637-a5ad85a9bf1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("07857d2a-bf34-4950-9637-a5ad85a9bf1e")) {
#                     Plotly.newPlot(
#                         '07857d2a-bf34-4950-9637-a5ad85a9bf1e',
# ...

# %%
media = dados2.mean().index.tolist()

# %%
media.insert(0, 'Unidade da Federação')

# %%
base = dados2[media]

# %%
base
# Out:
#       Unidade da Federação   2007/Ago  ...     2020/Jul          Total
# 0              11 Rondônia    4209.37  ...   7407388.24   929129659.72
# 1                  12 Acre   10470.07  ...   1163813.08   420668039.63
# 2              13 Amazonas   35752.72  ...  13358514.02  1771654871.23
# 3               14 Roraima    4785.91  ...   2739498.41   305010883.18
# 4                  15 Pará  181159.29  ...  27618727.51  4437115730.71
# 5                 16 Amapá   33672.74  ...   2155083.37   291637984.75
# 6             17 Tocantins    4113.76  ...   4489665.87   999998621.85
# 7              21 Maranhão  385330.18  ...  24374205.15  3632860959.84
# 8                 22 Piauí  220788.25  ...  18019214.49  2130616492.35
# 9                 23 Ceará  357904.65  ...  30809221.22  6197357245.98
# 10  24 Rio Grande do Norte  134605.36  ...  19593057.45  2477372149.60
# 11              25 Paraíba   97352.78  ...  15491469.06  2470550104.25
# ...

# %%
base.rename({'Unidade da Federação' : 'UF'}, axis=1, inplace=True)

# %%
base['Região'] = ""
base.head()
regiao = []

# %%
base['UF'].values
# Out:
# array(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco',
#        '27 Alagoas', '28 Sergipe', '29 Bahia', '31 Minas Gerais',
#        '32 Espírito Santo', '33 Rio de Janeiro', '35 São Paulo',
#        '41 Paraná', '42 Santa Catarina', '43 Rio Grande do Sul',
#        '50 Mato Grosso do Sul', '51 Mato Grosso', '52 Goiás',
#        '53 Distrito Federal'], dtype=object)

# %%
for estado in base['UF'].values:
  if estado.startswith('1'):
    regiao.append('Norte')
  elif estado.startswith('2'):
    regiao.append('Nordeste')
  elif estado.startswith('3'):
    regiao.append('Sudeste')
  elif estado.startswith('4'):
    regiao.append('Sul')
  elif estado.startswith('5'):
    regiao.append('Centro-Oeste')

# %%
base['Região'] = regiao

# %%
base.head(4)
# Out:
#             UF  2007/Ago  2007/Set  ...    2020/Jul         Total  Região
# 0  11 Rondônia   4209.37  16397.03  ...  7407388.24  929129659.72   Norte
# 1      12 Acre  10470.07  14001.71  ...  1163813.08  420668039.63   Norte
# 2  13 Amazonas  35752.72  45570.64  ... 13358514.02 1771654871.23   Norte
# 3   14 Roraima   4785.91  11858.63  ...  2739498.41  305010883.18   Norte
#
# [4 rows x 159 columns]

# %% [markdown]
# Agrupando por região:

# %%
regioes = base.groupby('Região')

# %%
regioes.size()
# Out:
# Região
# Centro-Oeste    4
# Nordeste        9
# Norte           7
# Sudeste         4
# Sul             3
# dtype: int64

# %%
regioes.get_group('Sudeste')
# Out:
#                    UF   2007/Ago  ...          Total   Região
# 16    31 Minas Gerais  971394.37  ... 19160106499.88  Sudeste
# 17  32 Espírito Santo   57408.11  ...  3139189177.73  Sudeste
# 18  33 Rio de Janeiro  469469.34  ...  9696362872.68  Sudeste
# 19       35 São Paulo 1665349.90  ... 38929353900.57  Sudeste
#
# [4 rows x 159 columns]

# %%
soma_regioes = regioes.sum()
soma_regioes
# Out:
#                2007/Ago   2007/Set  ...     2020/Jul          Total
# Região                              ...
# Centro-Oeste  634465.91 1994139.86  ...  81324695.69 11296363923.37
# Nordeste     1863465.81 4373676.55  ... 245911328.83 37384256278.39
# Norte         274163.86  702698.79  ...  58932690.50  9155215791.07
# Sudeste      3163621.72 8501821.51  ... 502177460.45 70925012450.86
# Sul          2298007.60 5707585.27  ... 211015091.26 33069711760.56
#
# [5 rows x 157 columns]

# %%
ax = sns.barplot(x = '2020/Jul', y=soma_regioes.index, data=soma_regioes)

# %%
regioes.get_group('Sudeste')
# Out:
#                    UF   2007/Ago  ...     2020/Jul          Total
# 16    31 Minas Gerais  971394.37  ... 120467187.34 19160106499.88
# 17  32 Espírito Santo   57408.11  ...  27460475.47  3139189177.73
# 18  33 Rio de Janeiro  469469.34  ...  71540227.33  9696362872.68
# 19       35 São Paulo 1665349.90  ... 282709570.31 38929353900.57
#
# [4 rows x 158 columns]

# %%
df = pd.DataFrame(columns = base.columns)
df
# Out:
# Empty DataFrame
# ...

# %%
for estado, data in regioes:
  maior = data.nlargest(1, '2007/Ago')
  df = df.append(maior)

# %%
regioes.agg('mean')
# Out:
#               2007/Ago   2007/Set  ...     2020/Jul          Total
# Região                             ...
# Centro-Oeste 158616.48  498534.97  ...  20331173.92  2824090980.84
# Nordeste     207051.76  485964.06  ...  27323480.98  4153806253.15
# Norte         39166.27  100385.54  ...   8418955.79  1307887970.15
# Sudeste      790905.43 2125455.38  ... 125544365.11 17731253112.72
# Sul          766002.53 1902528.42  ...  70338363.75 11023237253.52
#
# [5 rows x 157 columns]

# %% [markdown]
# Vamos ordenar os dados pela coluna 'Total', assim veremos quais foram os estados que mais gastaram. Selecionaremos os 5 que mais tiveram despesas e plotaremos um gráfico:

# %%
dados_ordenados_total = base.sort_values('Total', ascending = False)
dados_ordenados_total.head(5)
# Out:
#                       UF   2007/Ago  ...          Total   Região
# 19          35 São Paulo 1665349.90  ... 38929353900.57  Sudeste
# 16       31 Minas Gerais  971394.37  ... 19160106499.88  Sudeste
# 20             41 Paraná  554800.22  ... 13786964617.27      Sul
# 22  43 Rio Grande do Sul 1049252.33  ... 11958647088.33      Sul
# 18     33 Rio de Janeiro  469469.34  ...  9696362872.68  Sudeste
#
# [5 rows x 159 columns]

# %%
base_transposta = base.set_index('UF').T
base_transposta
# Out:
# UF        11 Rondônia      12 Acre  ...      52 Goiás 53 Distrito Federal
# 2007/Ago      4209.37     10470.07  ...     179395.82           191951.47
# 2007/Set     16397.03     14001.71  ...     418053.58           769966.25
# 2007/Out    133645.19     86200.85  ...    1198730.25          2165619.56
# 2007/Nov    346912.84    301323.68  ...    2712117.54          3813256.48
# 2007/Dez    711758.31    769612.36  ...    9293914.78          7121965.42
# ...               ...          ...  ...           ...                 ...
# 2020/Mai   8581195.13   2383895.48  ...   31870107.62         21437430.22
# 2020/Jun   9193593.76   2199920.70  ...   34437633.20         23479773.03
# 2020/Jul   7407388.24   1163813.08  ...   33499284.38         22233542.26
# Total    929129659.72 420668039.63  ... 4657348958.66       2429933198.76
# Região          Norte        Norte  ...  Centro-Oeste        Centro-Oeste
#
# [158 rows x 27 columns]

# %%
base_transposta.drop('Total', axis=0, inplace=True)
base_transposta.drop('Região', axis=0, inplace=True)

# %%
base_transposta = base_transposta.iloc[6:, 0:156]

# %%
estados_total = ['35 São Paulo', '31 Minas Gerais', '41 Paraná', '43 Rio Grande do Sul', '33 Rio de Janeiro']

# %%
dados_total = base_transposta[estados_total]

# %%
import plotly.io as pio
pio.renderers.default = 'colab'
dados_total.iplot( title='Cinco estados com maiores gastos na saúde', yTitle='Valor em Milhões', xTitle='Anos (2008 - 2020)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8f56ce9c-79cb-4810-b7ac-be617d74945f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8f56ce9c-79cb-4810-b7ac-be617d74945f")) {
#                     Plotly.newPlot(
#                         '8f56ce9c-79cb-4810-b7ac-be617d74945f',
# ...

# %% [markdown]
# Meu estado é o RJ, que por sinal já está plotado no desafio. Então plotarei outro estado, o de Santa Catarina.

# %%
estados_total2 = ['35 São Paulo', '31 Minas Gerais', '41 Paraná', '43 Rio Grande do Sul', '33 Rio de Janeiro', '42 Santa Catarina' ]
dados_total_2 = base_transposta[estados_total2]

# %%
import plotly.io as pio
pio.renderers.default = 'colab'
dados_total_2.iplot( title='Seis estados com maiores gastos na saúde', yTitle='Valor em Milhões', xTitle='Anos (2008 - 2020)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7e7dfdd3-0ce4-4d93-a230-6dfca7cdd8d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7e7dfdd3-0ce4-4d93-a230-6dfca7cdd8d3")) {
#                     Plotly.newPlot(
#                         '7e7dfdd3-0ce4-4d93-a230-6dfca7cdd8d3',
# ...
